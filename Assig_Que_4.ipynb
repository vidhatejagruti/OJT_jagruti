# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
np.random.seed(53)
coefficients = np.random.randn(6)
print(coefficients)
# Out:
# [ 0.20586487  1.16676171 -2.07263978 -0.63268717  0.99712645  2.3945538 ]

# %%
X=np.arange(-5,6.1,0.1)
plt.plot(X, 0.20586487*X**5+1.16676171*X**4+-2.07263978*X**3-0.63268717 *X**2-0.99712645*X+2.3945538)
plt.annotate('local maxima',xy=(6,2500),xytext=(4,2000),arrowprops=dict(facecolor='black',shrink=0.0))
plt.annotate('local minima',xy=(2,2),xytext=(2,500),arrowprops=dict(facecolor='black',shrink=0.0))

plt.xlabel('x')
plt.show()
2
# Out:
# 2
